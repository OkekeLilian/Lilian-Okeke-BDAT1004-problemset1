# %%
//question 1
int number1 = 5; //Data type is an interger
double number2 = 5.0; //data type is a double 
bool number3 = 5 > 1; //data type is a boolean
string number4 = "5"; //data type is a string
int number5 = 5 * 2;  // data type is a integer
string number6 = "5" + "5"; //data type is a string
string number7 = "5" + "2"; //data type is a string
float number8 = 5 / 2f;   // data type is a float
int number9= 5 % 2; //data type is an integer
int[] number10 = new int[] { 5, 2, 1 }; //data type is an integer array
bool number11 = 5 == 3; //data type is a boolean
double number12 = Math.PI; //  data type is a boolean

# %%
//question2
    //Question2A
string word = "Supercalifragilisticexpialidocious";
string letter = ""; //to store the letters in the word 
foreach(char c in word)
{
    if (char.IsLetter(c))
    {
        letter += c;
    }
}
Console.WriteLine("the word {0} has {1} letters",word,letter.Length);

# %%
//question2B 
string word = "Supercalifragilisticexpialidocious";
bool sub = word.Contains("ice"); 
if (sub)
{
    Console.WriteLine("the word {0} contains ice as a substring", word);
}
else
{
    Console.WriteLine("the word {0} does not contain ice as a substring", word);

}

# %%
//question2c

string firstword = "Supercalifragilisticexpialidocious";
string secondword = "Honorificabilitudinitatibus";
string thirdword = "Bababadalgharaghtakamminarronnkonn";
int length1st = firstword.Length;
int length2nd = secondword.Length;
int length3rd = thirdword.Length;


if ((length1st == length2nd) && (length1st > length3rd)) //doing this incase the length of the words are equal to eachother 
{
    Console.WriteLine("the longest words are {0} and {1}",firstword,secondword);
}
else if ((length1st == length3rd) && (length1st > length2nd))
{
    Console.WriteLine("the longest words are {0} and {1}", firstword, thirdword);
}
else if (length1st > length2nd)
{
    if (length1st > length3rd)
    {
        Console.WriteLine("the word {0} has the longest word", firstword);
        
    }
    else
    {
        Console.WriteLine("the word {0} has the longest word", thirdword);
    }
}
else if (length2nd > length3rd)
{
    if (length2nd > length1st)
    {
        Console.WriteLine("The word {0} has the longest word", secondword);
    }
    else
    {
        Console.WriteLine("The word {0} has the longest word", firstword);

    }
}

# %%
//question2D
var composer = new SortedSet<string>(); //sortedset to sort our set of words 
composer.Add("Berlioz");
composer.Add("Borodin");
composer.Add("Brian");
composer.Add("Bartok");
composer.Add("Bellini");
composer.Add("Buxtehude");
composer.Add("Bernstein");
string first = composer.Min; //gives the first word in the sorted Set
string last = composer.Max; //gives the last word in the sorted set
Console.WriteLine("the first composer is {0}", first);
Console.WriteLine("the last composer is {0}", last);

# %%
class question3
{
    public double area(double a, double b,double c)
    {

        double add = a + b + c;
        double s = add / 2;
        double input = s * (s - a) * (s - b) * (s - c);
        double area = Math.Sqrt(input);
        Console.WriteLine("the triangle has sides {0},{1},{2}", a, b, c);
        Console.WriteLine("The area of the triangle is {0}", area);
     return area;
    }
}
question3 Area = new question3();
Area.area(2,2,2);

# %%
//question4
int[] element = new int[5];
element[0] = 25;
element[1] = 47;
element[2] = 42;
element[3] = 56;
element[4] = 32;

string even_element = ""; //stores the even element 
string odd_element = ""; // stores the odd element 
foreach (int i in element) 
{
    int remainder = i % 2;
    if (remainder == 0)
    {
        even_element +=" "+Convert.ToString(i); //makes it read as string so it will not add as number 

    }
    else
    {
        odd_element += " " + Convert.ToString(i);
    }
}
Console.WriteLine("The Even element are: \n{0}",even_element.TrimStart()); //trimstart to remove the space in the begining 
Console.WriteLine("The Odd element are: \n{0}",odd_element.TrimStart());

# %%
//question5 
 class Question5
 {
     public void Inside(double x, double y, double x1, double y1, double x2, double y2)
     {
         bool yes = true; 
         bool no =  false;
         //A point(x,y) is inside a rectangle when x>=x1,x<=x2,y>=y1 and y<=y2
         if (x>=x1 && x<=x2 && y>=y1 && y<=y2) 
         {
             Console.WriteLine(yes);
             Console.WriteLine("the point ({0},{1}) lies in the rectangle",x,y);

         }
         else
         {
             Console.WriteLine(no);
             Console.WriteLine("the point ({0},{1}) does not lies in the rectangle",x,y);

         }
         }
}
Question5 Points = new Question5();
Points.Inside(1,1,0.3,0.5,1.1,0.7);
Console.WriteLine();
Points.Inside(1,1,0.5,0.2,1.1,2)

# %%
#question 6
def pig(word):
    vowels = 'aeiou' 
    word = word.lower() #changes the word to vowel 
    if word[0] in vowels:
        return word + 'way'
    else: 
        return word[1:] + word[0:1] + "ay" 
pig('happy') 
pig('enter')

# %%
#question7
def num(filepath):
          infile=open(filepath,'r')
          content = infile.read()
          words= content.split()
          bloodgroup = {"A": 0, "B": 0, "AB": 0, "O": 0, "OO": 0} #creating a dictionary for blood group with count to store count
          for word in words:
            if word in bloodgroup:
             bloodgroup[word]+=1 #add one to the count if blood group is in the dictionary
          for word,count in bloodgroup.items():
            if count == 0:
                print(f'There are no patients of blood type {word}')
            elif count ==1:
            
                print(f'There is {count} patients of blood type {word}')
            else:
                print(f'There are {count} of the blood type {word}')
          infile.close()

# %%
#Question 8
def filepath(filename): #to a function to collect the file path of your data
    file = open(filename,'r')
    data = file.readlines() #reads everyline in the file and seperates it with \n
    exchange_rate = {} #creating an empty dictionary to store currency and rates
    for line in data:
        parts = line.split() #split each words in the line 
        if len(parts) >=3: #we have more than three words in each line but we want to save it to three variables 
            currencys = parts[0] #saves first word to currencys
            rates = float (parts[1]) #saves second word to rates 
            currency_names= ''.join(parts[2:]) #joins the third  and the rest of the words together and store to currency 
            exchange_rate[currency]=rates #makes currency and rates into a dictionary i.e exchange_rate={currency:rates}
            return exchange_rate
    def conversion_to_Dollar(currency,amount,exchange_rate):
        amount=float(amount) #changes the amout to float so python will not read it as a string
        if currency in exchange_rate:
            rate = exchange_rate[currency]
            dollars = amount*rate
            return dollars
#AN EXAMPLE
filepath('C:\\Users\\USER\\Desktop\\currencies.txt')
conversion_to_Dollar("eur",100)

# %%
#question9
    string = 6 + 'a' 
# it will cause an indentation error

list = [2,3,4,5,6,7,8,9,9]
print(list[12])   
#it will cause an indexError

import math
number = math.sqrt(-1.0)
#it will cause an ValueError

print(x)
#it will cause a Nameerror

infile = open('example.txt','r')  
#the filenotfounderror

# %%
#question10
def frequencies(string):
   letters = 'abcdefghijklmnopqrstuvwxyz' 
   string = string.lower() #converts our inputed string to lower
   lettersdict = {char:0 for char in letters} #create a dictionary for each char and it's count 
   for char in string: 
       if char in letters:
         lettersdict[char]+=1 #adds 1 to the count if the letter is in the dictionary
   list =[lettersdict[char] for char in letters]  #stores the count of each letters in the dictionary in a list 
   return list
